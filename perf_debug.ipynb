# %%
import json

# %%
with open('instances_train2015.json') as fp:
    hicodet_train = json.load(fp=fp)

# %%
list(hicodet_train.keys())
# Out:
# ['annotation',
#  'filenames',
#  'empty',
#  'objects',
#  'verbs',
#  'correspondence',
#  'size',
#  'rare',
#  'non_rare']

# %%
hicodet_train['annotation']
# Out:
# [{'boxes_h': [[208.0, 33.0, 427.0, 300.0],
#    [213.0, 20.0, 438.0, 357.0],
#    [206.0, 33.0, 427.0, 306.0],
#    [209.0, 26.0, 444.0, 317.0]],
#   'boxes_o': [[59.0, 98.0, 572.0, 405.0],
#    [77.0, 115.0, 583.0, 396.0],
#    [61.0, 100.0, 571.0, 401.0],
#    [59.0, 99.0, 579.0, 395.0]],
#   'hoi': [152, 153, 154, 155],
#   'object': [44, 44, 44, 44],
#   'verb': [72, 76, 87, 98]},
#  {'boxes_h': [[262.0, 1.0, 638.0, 138.0]],
#   'boxes_o': [[162.0, 131.0, 258.0, 165.0]],
#   'hoi': [223],
#   'object': [3],
#   'verb': [57]},
#  {'boxes_h': [[567.0, 361.0, 580.0, 390.0]],
#   'boxes_o': [[74.0, 52.0, 510.0, 484.0]],
#   'hoi': [64],
#   'object': [16],
#   'verb': [57]},
#  {'boxes_h': [[223.0, 29.0, 484.0, 368.0], [221.0, 30.0, 485.0, 372.0]],
#   'boxes_o': [[269.0, 89.0, 363.0, 122.0], [261.0, 86.0, 367.0, 122.0]],
#   'hoi': [47, 48],
#   'object': [13, 13],
#   'verb': [20, 36]},
#  {'boxes_h': [[82.0, 154.0, 203.0, 272.0]],
#   'boxes_o': [[1.0, 176.0, 313.0, 422.0]],
# ...
